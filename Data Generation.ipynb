# %%
import seaborn as sns

# %%
# %config Completer.use_jedi = False

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('titanic').head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from sklearn.datasets import make_friedman3

# %%
data = make_friedman3()

# %%
data[0].shape , data[1].shape
# Out:
# ((100, 4), (100,))

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=data[0],columns=['a','b','c','d'])

# %%
dftarget= data[1]
# Out:
# <ipython-input-27-a0107d6f4eca>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.target= data[1]

# %%
df['target'] = data[1]

# %%
df
# Out:
#             a            b         c          d    target
# 0   57.865341   728.669281  0.228243   8.812868  1.235968
# 1   34.876706   365.105483  0.239146   1.424892  1.190763
# 2   13.469582  1303.174424  0.897016  10.963886  1.559274
# 3    2.400500   487.600647  0.918900   3.824183  1.565439
# 4   40.202041   640.807097  0.451892  10.863031  1.432847
# ..        ...          ...       ...        ...       ...
# 95   3.523627   911.025610  0.806312   2.032034  1.566000
# 96  57.749380  1554.264213  0.459586   1.990560  1.490126
# 97  31.234875   489.391021  0.069789   8.446750  0.830012
# 98  45.275513  1098.275550  0.022873   1.296980  0.506544
# 99  54.789635  1521.499629  0.678009   2.892359  1.517734
#
# [100 rows x 5 columns]

# %%
sns.pairplot(df)

# %%
from sklearn.datasets import make_gaussian_quantiles
# Construct dataset
X1, y1 = make_gaussian_quantiles(mean= [1,20], cov=20.,
                                 n_samples=10000, n_features=2,
                                 n_classes=3, random_state=1)
X1 = pd.DataFrame(X1,columns=['x','y'])
y1 = pd.Series(y1)

# %%
sns.scatterplot(x=X1.x, y=X1.y,hue=y1)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
from sklearn.datasets import make_gaussian_quantiles
import numpy as np
# Construct dataset
# Gaussian 1
X1, y1 = make_gaussian_quantiles(cov=3.,
                                 n_samples=10000, n_features=2,
                                 n_classes=2, random_state=1)
X1 = pd.DataFrame(X1,columns=['x','y'])
y1 = pd.Series(y1)

# Gaussian 2
X2, y2 = make_gaussian_quantiles(mean=(4, 4), cov=1,
                                 n_samples=5000, n_features=2,
                                 n_classes=2, random_state=1)
X2 = pd.DataFrame(X2,columns=['x','y'])
y2 = pd.Series(y2)
# Combine the gaussians
X1.shape
X2.shape
X = pd.DataFrame(np.concatenate((X1, X2)))
y = pd.Series(np.concatenate((y1, - y2 + 1)))
X.shape
# Out:
# (15000, 2)

# %%
X.iloc[:,0]
# Out:
# 0        0.759772
# 1        2.429896
# 2       -1.312662
# 3        1.544247
# 4        0.675905
#            ...
# 14995    5.058395
# 14996    3.920260
# 14997    4.471534
# 14998    4.425973
# 14999    5.010127
# Name: 0, Length: 15000, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
sns.scatterplot(x=X.iloc[:,0], y=X.iloc[:,1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=10000, n_features=2, n_informative=2, 
                    n_redundant=0, n_repeated=0, n_classes=3, n_clusters_per_class=1,random_state=2,
                          
                   flip_y=0,weights=[0.3,0.3,0.4])
X = pd.DataFrame(X)
y = pd.Series(y)

plt.figure(figsize=(15,10))

sns.scatterplot(x=X.iloc[:,0], y=X.iloc[:,1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=10000, n_features=2, n_informative=1, 
                    n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1,random_state=6,
                          
                   flip_y=0,weights=[0.5,0.5])
X = pd.DataFrame(X)
y = pd.Series(y)

plt.figure(figsize=(15,10))

sns.scatterplot(x=X.iloc[:,0], y=X.iloc[:,1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
X,y = make_classification(n_samples=10000, n_features=2, n_informative=2,n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1,class_sep=2,flip_y=0,weights=[0.5,0.5], random_state=17)
f, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,8))
sns.scatterplot(X[:,0],X[:,1],hue=y,ax=ax1);
ax1.set_title("No Noise");

# Generate noisy Data
X,y = make_classification(n_samples=10000, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1,class_sep=5,flip_y=0.5,weights=[0.5,0.5], random_state=17)
sns.scatterplot(X[:,0],X[:,1],hue=y,ax=ax2);
ax2.set_title("With Noise");
plt.show();
# Out:
# E:\SoftwareBinaries\miniconda\envs\test_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\SoftwareBinaries\miniconda\envs\test_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.datasets import make_classification
# Generate Balanced Data
X,y = make_classification(n_samples=1000, n_features=2, n_informative=2,n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=2,class_sep=2,flip_y=0,weights=[0.5,0.5], random_state=17)
f, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,8))
sns.scatterplot(X[:,0],X[:,1],hue=y,ax=ax1);
ax1.set_title("No Imbalance");


# Generate Imbalanced Data
X,y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_repeated=0, n_classes=2, n_clusters_per_class=1,class_sep=2,flip_y=0,weights=[0.99,0.01], random_state=17)
sns.scatterplot(X[:,0],X[:,1],hue=y,ax=ax2);
ax2.set_title("Imbalance 9:1 :: Negative:Postive");
plt.show();
# Out:
# E:\SoftwareBinaries\miniconda\envs\test_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\SoftwareBinaries\miniconda\envs\test_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X,y = make_classification(n_samples=10, n_features=8, n_informative=7, n_redundant=1, n_repeated=0 , n_classes=2,random_state=6)

# %%
X.var(axis=0)
# Out:
# array([2.1475922 , 1.49755226, 2.44450667, 7.53107926, 1.81416637,
#        3.20433379, 2.31842024, 1.64164825])

# %%
df = pd.DataFrame(X)

# %%
sns.pairplot(df, kind = 'reg')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot= True,cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
# %config Completer.use_jedi =False
