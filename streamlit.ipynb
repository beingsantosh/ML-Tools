# %%
import streamlit as st
import pandas as pd

# %%
st.write('My line of code in streamlit')
# Out:
# 2021-03-03 11:06:45.347 WARNING root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run E:\SoftwareBinaries\miniconda\envs\test_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
df = pd.read_csv("Corona_Updated.csv")

# %%
df.Temprature.plot()
# Out:
# <AxesSubplot:>

# %%
st.line_chart(df.Temprature)

# %% [markdown]
# ## Simply run
